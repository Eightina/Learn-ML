# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder
from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LogisticRegression
import re
from category_encoders import *
import optuna
import sklearn

# %%
df_train= pd.read_csv('df_train.csv')
df_test = pd.read_csv('df_test.csv')

# %%
df_train
# Out:
#      Survived  Pclass  Cabin_section  Companion  Family_Survival  Sex_male  \
# 0           0       3       0.299854          1              0.5         1
# 1           1       1       0.593220          1              0.5         0
# 2           1       3       0.299854          0              0.5         0
# 3           1       1       0.593220          1              0.0         0
# 4           0       3       0.299854          0              0.5         1
# ..        ...     ...            ...        ...              ...       ...
# 886         0       2       0.299854          0              0.5         1
# 887         1       1       0.744681          0              0.5         0
# 888         0       3       0.299854          3              0.0         0
# 889         1       1       0.593220          0              0.5         1
# 890         0       3       0.299854          0              0.5         1
#
#      FareBin  AgeBin
# 0          0       1
# 1          4       2
# 2          1       1
# 3          4       2
# 4          1       2
# ..       ...     ...
# 886        2       1
# 887        3       1
# 888        3       0
# 889        3       1
# 890        0       2
#
# [891 rows x 8 columns]

# %%
df_test
# Out:
#      Pclass  Cabin_section  Companion  Family_Survival  Sex_male  FareBin  \
# 0         3       0.299854          0              0.5         1        0
# 1         3       0.299854          1              0.5         0        0
# 2         2       0.299854          0              0.5         1        1
# 3         3       0.299854          0              0.5         1        1
# 4         3       0.299854          2              1.0         0        2
# ..      ...            ...        ...              ...       ...      ...
# 413       3       0.299854          0              0.5         1        1
# 414       1       0.593220          0              1.0         0        4
# 415       3       0.299854          0              0.5         1        0
# 416       3       0.299854          0              0.5         1        1
# 417       3       0.299854          2              1.0         1        3
#
#      AgeBin
# 0         2
# 1         2
# 2         3
# 3         1
# 4         1
# ..      ...
# 413       1
# 414       2
# 415       2
# 416       1
# 417       0
#
# [418 rows x 7 columns]

# %%
def objective(trial):
    k=55
    accuracy_sum = 0
    for i in range(k):
        data, target = df_train.drop('Survived', axis=1), df_train.Survived
        train_x, valid_x, train_y, valid_y = train_test_split(data, target, test_size=0.02)
        dtrain = lgb.Dataset(train_x, label=train_y)

        param = {
            "objective": "binary",
            "metric": "binary_error",
            "verbosity": -1,

            "boosting_type": "gbdt",


            
            # 'colsample_bytree': trial.suggest_float("colsample_bytree", 0.5, 0.9),
            # 'subsample': trial.suggest_float("subsample", 0.6, 0.8),
            'learning_rate': trial.suggest_float("learning_rate", 0.005, 0.05),
            'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
            'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
            "num_leaves": trial.suggest_int("num_leaves", 2, 256),
            "n_estimators": trial.suggest_int("n_estimators", 16, 64),
            "feature_fraction": trial.suggest_float("feature_fraction", 0.4, 1.0),
            "bagging_fraction": trial.suggest_float("bagging_fraction", 0.4, 1.0),
            "bagging_freq": trial.suggest_int("bagging_freq", 1, 7),
            "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
            'seed': 42
        }

        gbm = lgb.train(param, dtrain)
        preds = gbm.predict(valid_x)
        pred_labels = np.rint(preds)
        accuracy_sum += sklearn.metrics.accuracy_score(valid_y, pred_labels)
    accuracy = accuracy_sum/k
    return accuracy

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=500)
# Out:
# [I 2021-09-01 12:58:39,848] A new study created in memory with name: no-name-d486b348-def9-4838-92ed-65a276734ba3
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [I 2021-09-01 12:58:39,988] Trial 0 finished with value: 0.8212290502793296 and parameters: {'learning_rate': 0.037319151999060746, 'lambda_l1': 0.02360108157578671, 'lambda_l2': 0.24509166636330817, 'num_leaves': 243, 'n_estimators': 43, 'feature_fraction': 0.7462005655290086, 'bagging_fraction': 0.6776424098822691, 'bagging_freq': 5, 'min_child_samples': 39}. Best is trial 0 with value: 0.8212290502793296.
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [I 2021-09-01 12:58:40,080] Trial 1 finished with value: 0.794413407821229 and parameters: {'learning_rate': 0.026042145282646645, 'lambda_l1': 7.105701091204313e-06, 'lambda_l2': 4.0214774142095455e-08, 'num_leaves': 167, 'n_estimators': 21, 'feature_fraction': 0.5442006605517101, 'bagging_fraction': 0.6509624039637112, 'bagging_freq': 6, 'min_child_samples': 76}. Best is trial 0 with value: 0.8212290502793296.
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [I 2021-09-01 12:58:40,234] Trial 2 finished with value: 0.8234636871508381 and parameters: {'learning_rate': 0.037102128784550444, 'lambda_l1': 0.00010544123552471216, 'lambda_l2': 0.015767496384489026, 'num_leaves': 254, 'n_estimators': 45, 'feature_fraction': 0.5223193850677686, 'bagging_fraction': 0.8972489234815868, 'bagging_freq': 5, 'min_child_samples': 36}. Best is trial 2 with value: 0.8234636871508381.
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [I 2021-09-01 12:58:40,334] Trial 3 finished with value: 0.8027932960893855 and parameters: {'learning_rate': 0.030527840336431425, 'lambda_l1': 1.776765631937931e-08, 'lambda_l2': 3.867324452188824e-08, 'num_leaves': 106, 'n_estimators': 16, 'feature_fraction': 0.9386218152685029, 'bagging_fraction': 0.5110286464913694, 'bagging_freq': 1, 'min_child_samples': 22}. Best is trial 2 with value: 0.8234636871508381.
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [I 2021-09-01 12:58:40,439] Trial 4 finished with value: 0.7776536312849162 and parameters: {'learning_rate': 0.030739423636526347, 'lambda_l1': 0.0005295799195406913, 'lambda_l2': 2.766375649016036e-06, 'num_leaves': 154, 'n_estimators': 26, 'feature_fraction': 0.932541636549525, 'bagging_fraction': 0.7277937571157964, 'bagging_freq': 2, 'min_child_samples': 82}. Best is trial 2 with value: 0.8234636871508381.
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [I 2021-09-01 12:58:40,566] Trial 5 finished with value: 0.8033519553072626 and parameters: {'learning_rate': 0.020685648305353896, 'lambda_l1': 1.933293617334591, 'lambda_l2': 1.832751854512891, 'num_leaves': 182, 'n_estimators': 46, 'feature_fraction': 0.8464531039373604, 'bagging_fraction': 0.4806363970825084, 'bagging_freq': 3, 'min_child_samples': 46}. Best is trial 2 with value: 0.8234636871508381.
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [I 2021-09-01 12:58:40,725] Trial 6 finished with value: 0.8430167597765363 and parameters: {'learning_rate': 0.028769312740815976, 'lambda_l1': 0.004147574896974515, 'lambda_l2': 0.17229766824745282, 'num_leaves': 141, 'n_estimators': 38, 'feature_fraction': 0.7211277105472573, 'bagging_fraction': 0.9478662404442278, 'bagging_freq': 7, 'min_child_samples': 24}. Best is trial 6 with value: 0.8430167597765363.
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [I 2021-09-01 12:58:40,826] Trial 7 finished with value: 0.7983240223463687 and parameters: {'learning_rate': 0.03508396137533228, 'lambda_l1': 0.000317655897253951, 'lambda_l2': 3.812835602509263e-08, 'num_leaves': 56, 'n_estimators': 18, 'feature_fraction': 0.7277999227752294, 'bagging_fraction': 0.4338394697254796, 'bagging_freq': 3, 'min_child_samples': 28}. Best is trial 6 with value: 0.8430167597765363.
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [I 2021-09-01 12:58:40,935] Trial 8 finished with value: 0.7860335195530727 and parameters: {'learning_rate': 0.03665665717546083, 'lambda_l1': 0.09946459721548413, 'lambda_l2': 0.026850796186411487, 'num_leaves': 69, 'n_estimators': 36, 'feature_fraction': 0.8952363673075503, 'bagging_fraction': 0.5840592691948046, 'bagging_freq': 5, 'min_child_samples': 70}. Best is trial 6 with value: 0.8430167597765363.
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [I 2021-09-01 12:58:41,032] Trial 9 finished with value: 0.6564245810055865 and parameters: {'learning_rate': 0.020743920459030424, 'lambda_l1': 3.064788638210502e-08, 'lambda_l2': 0.0006046354191126096, 'num_leaves': 123, 'n_estimators': 17, 'feature_fraction': 0.565295701387794, 'bagging_fraction': 0.7991021235467535, 'bagging_freq': 4, 'min_child_samples': 97}. Best is trial 6 with value: 0.8430167597765363.
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [I 2021-09-01 12:58:41,183] Trial 10 finished with value: 0.653631284916201 and parameters: {'learning_rate': 0.011822221389508744, 'lambda_l1': 6.03123945229807, 'lambda_l2': 0.0001390585809398153, 'num_leaves': 16, 'n_estimators': 35, 'feature_fraction': 0.4078199411463355, 'bagging_fraction': 0.9807742401335764, 'bagging_freq': 7, 'min_child_samples': 7}. Best is trial 6 with value: 0.8430167597765363.
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [I 2021-09-01 12:58:41,520] Trial 11 finished with value: 0.853072625698324 and parameters: {'learning_rate': 0.029103214389785158, 'lambda_l1': 9.621704843617674e-06, 'lambda_l2': 0.010863181920922822, 'num_leaves': 247, 'n_estimators': 41, 'feature_fraction': 0.6027486786481687, 'bagging_fraction': 0.9715547328513343, 'bagging_freq': 7, 'min_child_samples': 6}. Best is trial 11 with value: 0.853072625698324.
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [I 2021-09-01 12:58:41,818] Trial 12 finished with value: 0.8346368715083801 and parameters: {'learning_rate': 0.026599062682243876, 'lambda_l1': 2.3430375950370966e-06, 'lambda_l2': 0.0014571560036324947, 'num_leaves': 211, 'n_estimators': 39, 'feature_fraction': 0.6500343444551479, 'bagging_fraction': 0.9896629309584773, 'bagging_freq': 7, 'min_child_samples': 8}. Best is trial 11 with value: 0.853072625698324.
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [I 2021-09-01 12:58:41,968] Trial 13 finished with value: 0.7726256983240223 and parameters: {'learning_rate': 0.020924328760696255, 'lambda_l1': 0.004361298460864814, 'lambda_l2': 8.86644251334262, 'num_leaves': 209, 'n_estimators': 29, 'feature_fraction': 0.6526117671710827, 'bagging_fraction': 0.8643484392536018, 'bagging_freq': 7, 'min_child_samples': 19}. Best is trial 11 with value: 0.853072625698324.
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [I 2021-09-01 12:58:42,138] Trial 14 finished with value: 0.811173184357542 and parameters: {'learning_rate': 0.029942267496712437, 'lambda_l1': 3.1677030139942265e-06, 'lambda_l2': 0.026217655577385875, 'num_leaves': 90, 'n_estimators': 40, 'feature_fraction': 0.8073112259804928, 'bagging_fraction': 0.9124961976361544, 'bagging_freq': 6, 'min_child_samples': 58}. Best is trial 11 with value: 0.853072625698324.
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [I 2021-09-01 12:58:42,355] Trial 15 finished with value: 0.8122905027932962 and parameters: {'learning_rate': 0.01448515441029161, 'lambda_l1': 4.49742043417406e-05, 'lambda_l2': 0.3353157177896851, 'num_leaves': 140, 'n_estimators': 32, 'feature_fraction': 0.6596474632293374, 'bagging_fraction': 0.803673704431075, 'bagging_freq': 6, 'min_child_samples': 17}. Best is trial 11 with value: 0.853072625698324.
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [I 2021-09-01 12:58:42,692] Trial 16 finished with value: 0.8145251396648046 and parameters: {'learning_rate': 0.03368528091460553, 'lambda_l1': 2.7448500342717597e-07, 'lambda_l2': 2.370600618964241e-05, 'num_leaves': 200, 'n_estimators': 48, 'feature_fraction': 0.44525755013144797, 'bagging_fraction': 0.9420591186193812, 'bagging_freq': 7, 'min_child_samples': 5}. Best is trial 11 with value: 0.853072625698324.
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# ...
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [I 2021-09-01 12:59:55,577] Trial 294 finished with value: 0.8469273743016761 and parameters: {'learning_rate': 0.030226358710659283, 'lambda_l1': 0.007272705505756395, 'lambda_l2': 2.6352023682456286e-05, 'num_leaves': 123, 'n_estimators': 41, 'feature_fraction': 0.746357368467513, 'bagging_fraction': 0.7389190639653745, 'bagging_freq': 5, 'min_child_samples': 7}. Best is trial 237 with value: 0.8648044692737429.
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [I 2021-09-01 12:59:55,943] Trial 295 finished with value: 0.8391061452513966 and parameters: {'learning_rate': 0.032049923492008144, 'lambda_l1': 0.00024064004196497495, 'lambda_l2': 4.72011655292972e-06, 'num_leaves': 187, 'n_estimators': 41, 'feature_fraction': 0.9402812159355058, 'bagging_fraction': 0.7678117606948686, 'bagging_freq': 6, 'min_child_samples': 10}. Best is trial 237 with value: 0.8648044692737429.
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [I 2021-09-01 12:59:56,163] Trial 296 finished with value: 0.8469273743016761 and parameters: {'learning_rate': 0.03729672765502537, 'lambda_l1': 7.863630240951018e-07, 'lambda_l2': 0.00037980003872791136, 'num_leaves': 25, 'n_estimators': 47, 'feature_fraction': 0.7914770618635072, 'bagging_fraction': 0.8350480992810506, 'bagging_freq': 5, 'min_child_samples': 32}. Best is trial 237 with value: 0.8648044692737429.
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [I 2021-09-01 12:59:56,464] Trial 297 finished with value: 0.8413407821229051 and parameters: {'learning_rate': 0.03376435994860829, 'lambda_l1': 0.013309047401543503, 'lambda_l2': 2.7941924138016974e-06, 'num_leaves': 135, 'n_estimators': 42, 'feature_fraction': 0.9785455016801072, 'bagging_fraction': 0.6437486030781966, 'bagging_freq': 6, 'min_child_samples': 12}. Best is trial 237 with value: 0.8648044692737429.
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [I 2021-09-01 12:59:56,685] Trial 298 finished with value: 0.8262569832402236 and parameters: {'learning_rate': 0.02370867353061512, 'lambda_l1': 0.0029403575820835057, 'lambda_l2': 0.00010275476701450866, 'num_leaves': 142, 'n_estimators': 44, 'feature_fraction': 0.877281136917755, 'bagging_fraction': 0.7859933348203945, 'bagging_freq': 5, 'min_child_samples': 43}. Best is trial 237 with value: 0.8648044692737429.
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [I 2021-09-01 12:59:56,925] Trial 299 finished with value: 0.846368715083799 and parameters: {'learning_rate': 0.030956144515495606, 'lambda_l1': 0.0015266963806647603, 'lambda_l2': 0.006023039364026098, 'num_leaves': 221, 'n_estimators': 43, 'feature_fraction': 0.6890813989717347, 'bagging_fraction': 0.4055141117846903, 'bagging_freq': 7, 'min_child_samples': 9}. Best is trial 237 with value: 0.8648044692737429.

# %%
print("Besttrial:")
trial=study.best_trial
print("Value:",trial.value)
print("Params:")
for key, value in trial.params.items():
    print("{}:{}".format(key,value))
# Out:
# Besttrial:
# Value: 0.8648044692737429
# Params:
# learning_rate:0.03158565683348696
# lambda_l1:0.08532505700836993
# lambda_l2:4.223696785227407e-05
# num_leaves:8
# n_estimators:40
# feature_fraction:0.9972407351683353
# bagging_fraction:0.7361011501718898
# bagging_freq:6
# min_child_samples:9

# %%
def prepare_for_light_gbm(data,id_col,drop_cols,target_col):
    # Drop target column
    if target_col is not None:
        labels = data[target_col]
        drop_cols = drop_cols + [target_col]
    else:
        labels = []

    if id_col is not None:
        ids = data[id_col]
        drop_cols = drop_cols + [id_col]
    else:
        ids = []

    if drop_cols is not None:
        data = data.drop(drop_cols, axis=1)

    # Create LGB mats
    lgb_data = lgb.Dataset(data, label=labels, free_raw_data=False,
                           feature_name=list(data.columns), 
                           categorical_feature='auto')

    return lgb_data, labels, ids, data

train_split_df, valid_split_df = train_test_split(df_train, test_size=0.4)
columns_to_drop = ['Ticket', 'Cabin', 'Name']
(train_lgb_dataset, train_labels,
     train_ids, train_split_df) = prepare_for_light_gbm(
        train_split_df,drop_cols=[],id_col=None, target_col='Survived')

(valid_lgb_dataset, valid_labels,
     valid_ids, valid_split_df) = prepare_for_light_gbm(
        valid_split_df,drop_cols=[], id_col=None,target_col='Survived')

test_lgb_dataset, _, _, test_df = prepare_for_light_gbm(
        df_test,drop_cols=[],id_col=None, target_col=None)

    # Prepare data set using all the training data
(train_valid_lgb_dataset, train_valid_labels,
     _, train_valid_df) = prepare_for_light_gbm(
        df_train,drop_cols=[],id_col=None, target_col='Survived')

# %%
add = {     "objective": "binary",
            "metric": "binary_error",
            "verbosity": -1,

            "boosting_type": "gbdt"}

# %%
best_params = {}
best_params.update(add)
best_params.update(trial.params)
best_params
# Out:
# {'objective': 'binary',
#  'metric': 'binary_error',
#  'verbosity': -1,
#  'boosting_type': 'gbdt',
#  'learning_rate': 0.03158565683348696,
#  'lambda_l1': 0.08532505700836993,
#  'lambda_l2': 4.223696785227407e-05,
#  'num_leaves': 8,
#  'n_estimators': 40,
#  'feature_fraction': 0.9972407351683353,
#  'bagging_fraction': 0.7361011501718898,
#  'bagging_freq': 6,
#  'min_child_samples': 9}

# %%
best_params = {'objective': 'binary',
 'metric': 'binary_error',
 'verbosity': -1,
 'boosting_type': 'gbdt',
 'learning_rate': 0.04325552852588823,
 'lambda_l1': 1.0571595190549928e-05,
 'lambda_l2': 0.006230373699462504,
 'num_leaves': 155,
 'n_estimators': 42,
 'feature_fraction': 0.7346730259993703,
 'bagging_fraction': 0.804201911633493,
 'bagging_freq': 1,
 'min_child_samples': 6}

# %%
k = 10
valid_preds, train_preds, result = 0, 0, 0
for m in range(k):
    
    print('Fitting model', m)

        # Prepare the data set for fold
    train_split_df, valid_split_df = train_test_split(df_train, test_size=0.4, random_state=42)
    (train_lgb_dataset, train_labels,train_ids, train_split_df) = prepare_for_light_gbm(
            train_split_df, target_col='Survived', id_col=None,
            drop_cols=[])
        
    (valid_lgb_dataset, valid_labels,valid_ids, valid_split_df) = prepare_for_light_gbm(
            valid_split_df, target_col='Survived', id_col=None,
            drop_cols=[])
        
        # Train
    gbm = lgb.train(best_params, train_lgb_dataset, num_boost_round=100000,
                        valid_sets=[train_lgb_dataset, valid_lgb_dataset],
                        early_stopping_rounds=50, verbose_eval=50)

        # Plot importance
    lgb.plot_importance(gbm)
    plt.show()

        # Predict
    valid_preds += gbm.predict(valid_split_df, 
                                num_iteration=gbm.best_iteration) / k
    train_preds += gbm.predict(train_split_df, 
                                num_iteration=gbm.best_iteration) / k
    result += gbm.predict(df_test, num_iteration=gbm.best_iteration) / k
# Out:
# Fitting model 0
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [39]	training's binary_error: 0.108614	valid_1's binary_error: 0.176471
# D:\programs\envs\python36\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Fitting model 1
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [39]	training's binary_error: 0.108614	valid_1's binary_error: 0.176471
# Fitting model 2
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [39]	training's binary_error: 0.108614	valid_1's binary_error: 0.176471
# Fitting model 3
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [39]	training's binary_error: 0.108614	valid_1's binary_error: 0.176471
# Fitting model 4
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [39]	training's binary_error: 0.108614	valid_1's binary_error: 0.176471
# Fitting model 5
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [39]	training's binary_error: 0.108614	valid_1's binary_error: 0.176471
# Fitting model 6
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [39]	training's binary_error: 0.108614	valid_1's binary_error: 0.176471
# Fitting model 7
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [39]	training's binary_error: 0.108614	valid_1's binary_error: 0.176471
# Fitting model 8
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [39]	training's binary_error: 0.108614	valid_1's binary_error: 0.176471
# Fitting model 9
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [39]	training's binary_error: 0.108614	valid_1's binary_error: 0.176471

# %%
result_write = np.int32(result > 0.5)
temp=pd.read_csv('test.csv')
submission={'PassengerId':temp.PassengerId,'Survived':result_write}
df_submission=pd.DataFrame(submission)
df_submission.to_csv('submission_opt9.csv', index=False)
